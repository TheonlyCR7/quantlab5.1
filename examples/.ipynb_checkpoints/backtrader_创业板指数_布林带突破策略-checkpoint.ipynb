# %%
import sys
sys.path.append('../')
from matplotlib import rcParams
rcParams['font.family'] = 'SimHei'
# %matplotlib inline
import backtrader as bt

# %%
from datafeed.dataloader import CSVDataloader
df = CSVDataloader.get_backtrader_df('159915.SZ')
df.dropna()
# Out:
#              open   high    low  close   volume  openinterest
# date
# 2011-12-09  0.795  0.814  0.795  0.797  1061772             0
# 2011-12-12  0.790  0.803  0.790  0.790   311065             0
# 2011-12-13  0.788  0.788  0.763  0.768   967444             0
# 2011-12-14  0.768  0.777  0.755  0.760   816095             0
# 2011-12-15  0.755  0.764  0.747  0.752   417005             0
# ...           ...    ...    ...    ...      ...           ...
# 2024-05-22  1.819  1.825  1.816  1.820   763988             0
# 2024-05-23  1.837  1.837  1.807  1.811  6599889             0
# 2024-05-24  1.804  1.821  1.778  1.781  6828319             0
# 2024-05-27  1.784  1.788  1.767  1.770  1965943             0
# 2024-05-28  1.784  1.786  1.781  1.784   261221             0
#
# [3025 rows x 6 columns]

# %%
class roc_trend(bt.Strategy):
    # 参数定义
    params = dict(
        period=20,  # 动量周期
    )

    def __init__(self):
        self.roc = bt.indicators.ROC(self.data, period=self.p.period)
        #self.roc = bt.talib.ROC(self.data, period=self.p.period)
    
    def next(self):
        if not self.position:  # not in the market
            if self.roc[-1] > 0.08:  # if fast crosses slow to the upside
                self.order_target_percent(self.data,0.99)  # enter long
                #self.buy()  # enter long

        elif self.roc[-1] < 0:  # in the market & cross to the downside
            self.close()  # close long position

# %%
cerebro = bt.Cerebro()
cerebro.broker.setcash(100*10000.0)
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

data = bt.feeds.PandasData(dataname=df)
cerebro.adddata(data)


print('初始资金: %.2f' % cerebro.broker.getvalue())
cerebro.addstrategy(roc_trend)
strats = cerebro.run()

print('期末资金: %.2f' % cerebro.broker.getvalue())
# Out:
# 初始资金: 1000000.00
# 期末资金: 8482482.51

# %%
strat0 = strats[0]
pyfolio = strat0.analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfolio.get_pf_items()
transactions
# Out:
#                             amount  price  sid symbol        value
# date
# 2012-02-22 00:00:00+00:00  1341463  0.738    0         -989999.694
# 2012-03-23 00:00:00+00:00 -1341463  0.750    0         1006097.250
# 2012-12-27 00:00:00+00:00  1414819  0.712    0        -1007351.128
# 2013-04-02 00:00:00+00:00 -1414819  0.877    0         1240796.263
# 2013-05-07 00:00:00+00:00  1298055  0.951    0        -1234450.305
# ...                            ...    ...  ...    ...          ...
# 2022-11-15 00:00:00+00:00 -3725392  2.297    0         8557225.424
# 2023-01-19 00:00:00+00:00  3478728  2.465    0        -8575064.520
# 2023-02-21 00:00:00+00:00 -3478728  2.401    0         8352425.928
# 2024-03-06 00:00:00+00:00  4699488  1.773    0        -8332192.224
# 2024-04-01 00:00:00+00:00 -4699488  1.780    0         8365088.640
#
# [64 rows x 5 columns]

# %%
import quantstats as qs
qs.reports.metrics(returns)
# Out:
# D:\quant\lab\venv\lib\site-packages\quantstats\stats.py:510: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   returns = _utils._prepare_returns(returns, rf).resample(resolution).sum()
#                     Strategy
# ------------------  ----------
# Start Period        2011-12-09
# End Period          2024-05-28
# Risk-Free Rate      0.0%
# Time in Market      32.0%
#
# Cumulative Return   748.25%
# CAGR﹪              12.56%
#
# Sharpe              1.05
# Prob. Sharpe Ratio  99.99%
# Sortino             1.65
# Sortino/√2          1.17
# Omega               1.37
#
# Max Drawdown        -16.81%
# Longest DD Days     1185
#
# Gain/Pain Ratio     0.37
# Gain/Pain (1M)      2.57
#
# Payoff Ratio        1.18
# Profit Factor       1.37
# Common Sense Ratio  1.89
# CPC Index           0.87
# Tail Ratio          1.38
# Outlier Win Ratio   12.47
# Outlier Loss Ratio  2.6
#
# MTD                 0.0%
# 3M                  0.39%
# 6M                  0.39%
# YTD                 0.39%
# 1Y                  0.39%
# 3Y (ann.)           0.92%
# 5Y (ann.)           9.3%
# 10Y (ann.)          12.75%
# All-time (ann.)     12.56%
#
# Avg. Drawdown       -4.35%
# Avg. Drawdown Days  59
# Recovery Factor     13.95
# Ulcer Index         0.08
# Serenity Index      2.9

# %%
qs.reports.basic(returns)
# Out:
# <h4>Performance Metrics</h4>
# D:\quant\lab\venv\lib\site-packages\quantstats\stats.py:510: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   returns = _utils._prepare_returns(returns, rf).resample(resolution).sum()
#                     Strategy
# ------------------  ----------
# Start Period        2011-12-09
# End Period          2024-05-28
# Risk-Free Rate      0.0%
# Time in Market      32.0%
#
# Cumulative Return   748.25%
# CAGR﹪              12.56%
#
# Sharpe              1.05
# Prob. Sharpe Ratio  99.99%
# Sortino             1.65
# Sortino/√2          1.17
# Omega               1.37
#
# Max Drawdown        -16.81%
# Longest DD Days     1185
#
# Gain/Pain Ratio     0.37
# Gain/Pain (1M)      2.57
#
# Payoff Ratio        1.18
# Profit Factor       1.37
# Common Sense Ratio  1.89
# CPC Index           0.87
# Tail Ratio          1.38
# Outlier Win Ratio   12.47
# Outlier Loss Ratio  2.6
#
# MTD                 0.0%
# 3M                  0.39%
# 6M                  0.39%
# YTD                 0.39%
# 1Y                  0.39%
# 3Y (ann.)           0.92%
# 5Y (ann.)           9.3%
# 10Y (ann.)          12.75%
# All-time (ann.)     12.56%
#
# Avg. Drawdown       -4.35%
# Avg. Drawdown Days  59
# Recovery Factor     13.95
# Ulcer Index         0.08
# Serenity Index      2.9
# <h4>Strategy Visualization</h4>
